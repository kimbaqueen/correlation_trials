# %%
import pandas as pd
import numpy as np
import plotly.express as px
# %matplotlib inline
from scipy import *

# %%
absentee_data = pd.read_csv('Absenteeism_at_work.csv')

# %%
absentee_data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
absentee_data.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
absentee_data.info
# Out:
# <bound method DataFrame.info of      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
# ...

# %%
import seaborn as sb

# %%
x = absentee_data[['Day of the week','Reason for absence','Month of absence','Age','Disciplinary failure','Service time','Transportation expense','Distance from Residence to Work','Pet','Absenteeism time in hours','Height','Body mass index','Hit target']]
sb.pairplot(x)

# %%
from scipy.stats import pearsonr

# %%
day = absentee_data['Day of the week']
reason = absentee_data['Reason for absence']
month = absentee_data['Month of absence']
age = absentee_data['Age']
discipline_failure = absentee_data['Disciplinary failure']
service_time = absentee_data['Service time']
trans_expense = absentee_data['Transportation expense']
distance = absentee_data['Distance from Residence to Work']
pet = absentee_data['Pet']
hours = absentee_data['Absenteeism time in hours']
height = absentee_data['Height']
bmi = absentee_data['Body mass index']
hit = absentee_data['Hit target']

# %% [markdown]
# # Correlation Using Scipy PearsonR

# %%
pearsonr_coefficient, p_value = pearsonr(day, reason)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient 0.116

# %%
pearsonr_coefficient, p_value = pearsonr(month, age)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient -0.002

# %%
pearsonr_coefficient, p_value = pearsonr(hit, discipline_failure)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient -0.148

# %%
pearsonr_coefficient, p_value = pearsonr(service_time, reason)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient 0.048

# %%
pearsonr_coefficient, p_value = pearsonr(trans_expense, distance)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient 0.262

# %%
pearsonr_coefficient, p_value = pearsonr(age, pet)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient -0.231

# %%
pearsonr_coefficient, p_value = pearsonr(hours, day)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient -0.124

# %%
pearsonr_coefficient, p_value = pearsonr(month, hours)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient 0.024

# %%
pearsonr_coefficient, p_value = pearsonr(bmi, height)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient -0.121

# %%
pearsonr_coefficient, p_value = pearsonr(pet, discipline_failure)
print('PearsonR Correlation Coefficient %0.3f'% (pearsonr_coefficient))
# Out:
# PearsonR Correlation Coefficient 0.019

# %%
corr = x.corr()
corr
# Out:
#                                  Day of the week  Reason for absence  \
# Day of the week                         1.000000            0.116319
# Reason for absence                      0.116319            1.000000
# Month of absence                       -0.006528           -0.083858
# Age                                     0.004459           -0.078608
# Disciplinary failure                   -0.015120           -0.545054
# Service time                            0.021252            0.048425
# Transportation expense                  0.033988           -0.119381
# Distance from Residence to Work         0.118026            0.161831
# Pet                                    -0.028885           -0.055911
# Absenteeism time in hours              -0.124361           -0.173116
# Height                                 -0.082133           -0.079267
# Body mass index                        -0.103578            0.037205
# Hit target                              0.030986            0.088943
#
# ...

# %%
sb.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation Using Numpy Corrcoef

# %%
np.corrcoef(absentee_data['Transportation expense'], absentee_data['Distance from Residence to Work'])
# Out:
# array([[1.        , 0.26218311],
#        [0.26218311, 1.        ]])

# %%
np.corrcoef(absentee_data['Age'], absentee_data['Pet'])
# Out:
# array([[ 1.      , -0.231226],
#        [-0.231226,  1.      ]])

# %% [markdown]
# # Correlation Using Scipy SpearmanR

# %%
from scipy.stats import spearmanr
import scipy.stats as st

# %%
spearmanr(absentee_data['Transportation expense'], absentee_data['Distance from Residence to Work'])
# Out:
# SpearmanrResult(correlation=0.287267232417557, pvalue=1.5881778161806322e-15)

# %%
st.pearsonr(absentee_data['Transportation expense'], absentee_data['Distance from Residence to Work'])
# Out:
# (0.262183110631908, 4.2533009832568887e-13)

# %% [markdown]
# # Visualization - Bar plot (Day, Reason)

# %%
sb.barplot(x=day, y=reason)
# Out:
# <AxesSubplot:xlabel='Day of the week', ylabel='Reason for absence'>

# %% [markdown]
# # Visualization - Line Graph (month, age)

# %%
sb.lineplot(x=month, y=age)
# Out:
# <AxesSubplot:xlabel='Month of absence', ylabel='Age'>

# %% [markdown]
# # Visualization - Scatter plot (hit target, discipline failure)

# %%
sb.scatterplot(x=discipline_failure, y=hit)
# Out:
# <AxesSubplot:xlabel='Disciplinary failure', ylabel='Hit target'>

# %% [markdown]
# # Visualization - Scatter plot (service time, reason for absence)

# %%
sb.scatterplot(x=service_time, y=reason)
# Out:
# <AxesSubplot:xlabel='Service time', ylabel='Reason for absence'>

# %% [markdown]
# # Visualization - Scatter plot (transportation expense, distance)

# %%
sb.scatterplot(x=trans_expense, y=distance)
# Out:
# <AxesSubplot:xlabel='Transportation expense', ylabel='Distance from Residence to Work'>

# %% [markdown]
# # Visualization - Histogram Plot (age, pet)

# %%
sb.histplot(x=pet, y=age, bins=20)
# Out:
# <AxesSubplot:xlabel='Pet', ylabel='Age'>

# %% [markdown]
# # Visualization - Histogram Plot (hours, day)

# %%
sb.histplot(x=hours, y=day, bins=20)
# Out:
# <AxesSubplot:xlabel='Absenteeism time in hours', ylabel='Day of the week'>

# %% [markdown]
# # Visualization - Histogram Plot (Month, hours)

# %%
sb.histplot(x=month, y=hours, bins=20)
# Out:
# <AxesSubplot:xlabel='Month of absence', ylabel='Absenteeism time in hours'>

# %% [markdown]
# # Visualization - Histogram Plot (BMI, height)

# %%
sb.histplot(x=bmi, y=height, bins=20)
# Out:
# <AxesSubplot:xlabel='Body mass index', ylabel='Height'>

# %% [markdown]
# # Visualization - Bar plot (pet, disciplinary failure)

# %%
sb.barplot(x=pet, y=discipline_failure)
# Out:
# <AxesSubplot:xlabel='Pet', ylabel='Disciplinary failure'>
